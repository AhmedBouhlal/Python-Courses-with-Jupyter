# %% [markdown]
# # 🎯 Matplotlib Mastery Plan (Zero → Expert)
# ## 🔷 STAGE 1 — Fundamentals (The Foundation)
# ✅ What You’ll Learn:
# - Basic plotting: plot(), scatter(), bar()
#
# - Axes, titles, labels, legends
#
# - Line styles, colors, markers
#
# - Save plots as PNG, SVG, PDF
#
# 🧪 Example:

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4]
y = [2, 4, 1, 3]

plt.plot(x, y, label="Line A", color="blue", linestyle="--", marker="o")
plt.title("Simple Line Plot")
plt.xlabel("X Axis")
plt.ylabel("Y Axis")
plt.legend()
plt.grid(True)
plt.savefig("plot.png")  # Save to file
plt.show()

# %% [markdown]
# ## 🔶 STAGE 2 — Charts & Visualizations
# ✅ What You’ll Learn:
# - bar(), barh(), pie(), hist()
#
# - subplot() and plt.subplots()
#
# - Custom ticks, axis limits, annotations
#
# 🧪 Example:

# %%
import numpy as np

data = np.random.randn(1000)
plt.hist(data, bins=30, color="purple", alpha=0.7)
plt.title("Histogram Example")
plt.show()

# %% [markdown]
# ## 🔷 STAGE 3 — Subplots, Layouts & Grids
# ✅ What You’ll Learn:
# - plt.subplot() (manual layout)
#
# - plt.subplots() (automatic grid)
#
# - Sharing axes, figure sizes
#
# - Tight layout, spacing, nested plots
#
# 🧪 Example:

# %%
fig, axs = plt.subplots(2, 2, figsize=(8, 6))
axs[0, 0].plot([1, 2], [3, 4])
axs[0, 1].bar([1, 2], [4, 2])
axs[1, 0].scatter([1, 2], [5, 6])
axs[1, 1].hist(np.random.randn(100))
fig.suptitle("Subplot Grid Example")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 🔶 STAGE 4 — Styling, Themes & Customization
# ✅ What You’ll Learn:
# - Change fonts, background, colors
#
# - Custom colormaps
#
# - rcParams for global styles
#
# - Dark mode plots

# %% [markdown]
# ## 🔷 STAGE 5 — Advanced Plot Types
# ✅ What You’ll Learn:
# - imshow() for image data
#
# - Contour plots (contour, contourf)
#
# - 3D plots with Axes3D
#
# - Heatmaps and custom colorbars

# %% [markdown]
# ## 🔶 STAGE 6 — Interactive & Animated Plots
# ✅ What You’ll Learn:
# - Use %matplotlib notebook for interactivity
#
# - Create animated charts (FuncAnimation)
#
# - Interactive mouse-over plots
#
# - Real-time plot updates (live sensors/data)

# %% [markdown]
# ## 🔷 STAGE 7 — Export & Integration
# ✅ What You’ll Learn:
# - Export to SVG, PDF, PNG, high DPI
#
# - Embed in Jupyter, HTML, or PyQt
#
# - Use Matplotlib in GUI apps (Tkinter, PyQt, streamlit)
#
# - Integrate with Pandas and Seaborn

# %% [markdown]
# # 🔷 STAGE 1 – Matplotlib Fundamentals (Beginner to Confident)

# %% [markdown]
# ## 🧠 Concept: What is Matplotlib?
# Matplotlib is the most powerful Python library for 2D plotting. It’s used to create everything from simple line plots to complex dashboards.
#     The core module for plotting is:

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ### ✅ PART 1 — Your First Plot

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4]
y = [2, 4, 6, 8]

plt.plot(x, y)       # Plot line
plt.show()           # Show the plot

# %% [markdown]
# ### ✅ PART 2 — Add Labels, Title, and Grid

# %%
plt.plot(x, y)
plt.title("My First Plot")
plt.xlabel("X Axis")
plt.ylabel("Y Axis")
plt.grid(True)
plt.show()

# %% [markdown]
# 🧠 .title(), .xlabel(), and .ylabel() help make your plot understandable.
# ### ✅ PART 3 — Customize Line Style, Color, and Marker

# %%
plt.plot(x, y, color="red", linestyle="--", marker="o", label="Line A")
plt.legend()
plt.title("Styled Plot")
plt.xlabel("X")
plt.ylabel("Y")
plt.grid(True)
plt.show()

# %% [markdown]
# | Option      | Example         | Meaning                |
# | ----------- | --------------- | ---------------------- |
# | `color`     | `"blue"`        | Line color             |
# | `linestyle` | `"--"` or `":"` | Dashed / dotted        |
# | `marker`    | `"o"`           | Circle markers         |
# | `label`     | `"Line A"`      | Used in legend display |

# %% [markdown]
# ### ✅ PART 4 — Save Your Plot to a File

# %%
plt.plot(x, y)
plt.title("Saved Plot")
plt.savefig("my_plot.png")  # Save as image
plt.show()

# %% [markdown]
# 🔥 You can also save as:

# %%
plt.savefig("plot.svg")  # Vector format
plt.savefig("plot.pdf")  # PDF for print

# %% [markdown]
# ### ✅ PART 5 — Multiple Lines in One Plot

# %%
x = [1, 2, 3, 4]
y1 = [1, 4, 9, 16]
y2 = [2, 3, 6, 12]

plt.plot(x, y1, label="y = x^2", color="green")
plt.plot(x, y2, label="y = 3x", color="orange")
plt.title("Multiple Lines")
plt.xlabel("X")
plt.ylabel("Y")
plt.legend()
plt.show()

# %% [markdown]
# ### ✅ PART 6 — Add Axis Limits and Ticks

# %%
plt.plot(x, y1)
plt.title("Axis Control")
plt.xlim(0, 5)
plt.ylim(0, 20)
plt.xticks([1, 2, 3, 4])
plt.yticks([0, 5, 10, 15, 20])
plt.grid(True)
plt.show()

# %% [markdown]
# ### 🧠 MINI CHALLENGE: Plot this
# Plot the following:
#
# - x = [0, 1, 2, 3, 4, 5]
#
# - y1 = [0, 1, 4, 9, 16, 25] (label = "y = x²", red dashed, marker "x")
#
# - y2 = [0, 1, 2, 3, 4, 5] (label = "y = x", green dotted, marker "o")
#
# - Add title, grid, legend, and save it as challenge_plot.png

# %%
x = [0, 1, 2, 3, 4, 5]
y1 = [0, 1, 4, 9, 16, 25]
y2 = [0, 1, 2, 3, 4, 5]

plt.plot(x, y1, label="y = x^2", color="red", linestyle="--", marker="x")
plt.plot(x, y2, label="y = x", color="green", linestyle=":", marker="o")
plt.title("Mini Challenge")
plt.legend()
plt.grid(True)
plt.xlabel("X")
plt.ylabel("Y")
plt.savefig("challenge_plot.png")
plt.show()

# %% [markdown]
# ## 🔶 STAGE 2 – Charts & Layouts in Matplotlib
# ### ✅ PART 1 — Bar Charts (plt.bar())
# Bar charts are great for comparing values between categories.

# %%
import matplotlib.pyplot as plt

categories = ['A', 'B', 'C', 'D']
values = [10, 25, 8, 15]

plt.bar(categories, values, color='skyblue')
plt.title("Bar Chart Example")
plt.xlabel("Category")
plt.ylabel("Value")
plt.grid(axis='y')
plt.show()

# %% [markdown]
# 📌 axis='y' enables horizontal grid lines.
# ### ✅ PART 2 — Horizontal Bar Charts (plt.barh())

# %%
plt.barh(categories, values, color='lightgreen')
plt.title("Horizontal Bar Chart")
plt.xlabel("Value")
plt.ylabel("Category")
plt.grid(axis='x')
plt.show()

# %% [markdown]
# ### ✅ PART 3 — Histogram (plt.hist())
# Histograms are for distributions (e.g. grades, heights, AI confidence scores).

# %%
import numpy as np

data = np.random.randn(1000)

plt.hist(data, bins=30, color='purple', alpha=0.7)
plt.title("Histogram of Random Data")
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.grid(True)
plt.show()

# %% [markdown]
# | Param            | Meaning        |
# | ---------------- | -------------- |
# | `bins=30`        | Number of bars |
# | `alpha=0.7`      | Transparency   |
# | `color="purple"` | Color of bars  |

# %% [markdown]
# ### ✅ PART 4 — Subplots with plt.subplot()
# This allows multiple plots in one figure.

# %%
x = [1, 2, 3, 4]
y1 = [1, 4, 9, 16]
y2 = [1, 2, 3, 4]

plt.subplot(1, 2, 1)
plt.plot(x, y1, color='red')
plt.title("Plot 1")

plt.subplot(1, 2, 2)
plt.plot(x, y2, color='blue')
plt.title("Plot 2")

plt.tight_layout()
plt.show()

# %% [markdown]
# 📌 subplot(1, 2, 1) = 1 row, 2 columns, plot #1

# %% [markdown]
# ### ✅ PART 5 — Subplots with plt.subplots()
# This is the modern & flexible way to build grid layouts:

# %%
fig, axs = plt.subplots(2, 2, figsize=(6, 6))

axs[0, 0].bar(['A', 'B'], [5, 7])
axs[0, 0].set_title("Bar")

axs[0, 1].plot([1, 2, 3], [3, 2, 5])
axs[0, 1].set_title("Line")

axs[1, 0].scatter([1, 2, 3], [3, 1, 4])
axs[1, 0].set_title("Scatter")

axs[1, 1].hist(np.random.randn(100), bins=20)
axs[1, 1].set_title("Histogram")

fig.suptitle("2x2 Subplot Example")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### ✅ MINI CHALLENGE:
# Create a subplot with 2 rows and 1 column:
#
# - Top plot: y = x^2
#
# - Bottom plot: A histogram of 100 random numbers (np.random.randn(100))
#
# Add:
#
# - Titles for both plots
#
# - Shared x-axis
#
# - Tight layout

# %%
fig, axs = plt.subplots(2, 1, figsize=(6, 6))
x = [1, 2, 3, 4]
y = [1, 4, 9, 16]

axs[0].plot(x, y, color='blue')
axs[0].set_title("y = x^2")
axs[0].grid(True)

axs[1].hist(np.random.randn(100), bins=40)
axs[1].set_title("Histogram")
axs[0].grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 🎨 STAGE 3 – Styling, Themes, and Global Settings
# ### ✅ PART 1 — Change Font Size, Font Type, and Title Styles
# 🔧 Customize title, labels, ticks:

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4]
y = [2, 4, 6, 8]

plt.plot(x, y, color='green')
plt.title("Styled Title", fontsize=18, fontweight='bold', color='purple')
plt.xlabel("X Axis", fontsize=12)
plt.ylabel("Y Axis", fontsize=12)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.grid(True)
plt.show()

# %% [markdown]
# ### ✅ PART 2 — Use Built-in Styles / Themes
# Matplotlib has built-in themes like "ggplot", "seaborn", "dark_background".

# %%
plt.style.use("ggplot")

plt.plot(x, y)
plt.title("Using ggplot Style")
plt.show()

# %% [markdown]
# ### ✅ PART 3 — Global Styling with rcParams
# plt.rcParams changes default behavior for all future plots.

# %%
plt.rcParams["figure.figsize"] = (6, 4)
plt.rcParams["lines.linewidth"] = 2
plt.rcParams["axes.titlesize"] = 16
plt.rcParams["axes.labelsize"] = 12
plt.rcParams["axes.facecolor"] = "#f4f4f4"
plt.rcParams["font.family"] = "monospace"

# %% [markdown]
# Then:

# %%
plt.plot(x, y)
plt.title("Global Style Plot")
plt.xlabel("X")
plt.ylabel("Y")
plt.grid(True)
plt.show()

# %% [markdown]
# ### ✅ PART 4 — Dark Mode Plotting 🌒

# %%
plt.style.use("dark_background")

x = [1, 2, 3, 4]
y = [1, 4, 9, 16]

plt.plot(x, y, color="cyan", marker="o")
plt.title("Dark Mode Plot")
plt.xlabel("X")
plt.ylabel("Y")
plt.grid(True)
plt.show()

# %% [markdown]
# 🧠 Works great for presentations or dashboards.
# ### ✅ PART 5 — Custom Color Maps (for heatmaps, scatter, etc.)

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.random.rand(100)
y = np.random.rand(100)
colors = np.random.rand(100)

plt.scatter(x, y, c=colors, cmap="viridis", s=100, alpha=0.7)
plt.title("Custom Colormap with Colorbar")
plt.grid(False)           # 👈 Disable grid before colorbar
plt.colorbar()            # Now it's clean
plt.show()
# Out:
# /tmp/ipykernel_12757/4288134544.py:11: MatplotlibDeprecationWarning: Auto-removal of grids by pcolor() and pcolormesh() is deprecated since 3.5 and will be removed two minor releases later; please call grid(False) first.
#   plt.colorbar()            # Now it's clean

# %% [markdown]
# ### 🔥 MINI CHALLENGE:
# Create a dark mode plot with:
#
# - Line y = x² using cyan dashed line and x markers
#
# - Title in bold green with font size 20
#
# - Axis labels in yellow
#
# - Use rcParams to set a custom grid color
#
# - Save it as dark_style_plot.png

# %%
plt.style.use("dark_background")
plt.plot([1, 2, 3, 4], [1, 4, 9, 16], color='cyan', linestyle="--", marker="x")
plt.title("Mini Challenge", fontsize=20, fontweight='bold', color='green')
plt.xlabel("X", color='yellow')
plt.ylabel("Y", color='yellow')
plt.savefig("dark_style_plot.png")

# %% [markdown]
# ## 🔷 STAGE 4 – Advanced Plot Types
# ### ✅ PART 1 — Show Images with imshow()
# Use imshow() to display 2D data as an image (heatmap style)

# %%
import matplotlib.pyplot as plt
import numpy as np

data = np.random.rand(10, 10)

plt.imshow(data, cmap="viridis", interpolation="nearest")
plt.title("Heatmap from Matrix")
plt.grid(False)
plt.colorbar()
plt.show()
# Out:
# /tmp/ipykernel_12757/1333906995.py:9: MatplotlibDeprecationWarning: Auto-removal of grids by pcolor() and pcolormesh() is deprecated since 3.5 and will be removed two minor releases later; please call grid(False) first.
#   plt.colorbar()

# %% [markdown]
# | Param           | Description                                             |
# | --------------- | ------------------------------------------------------- |
# | `cmap`          | Color scheme (`"viridis"`, `"hot"`, `"coolwarm"`, etc.) |
# | `interpolation` | Pixel smoothing method (`"nearest"` for raw)            |

# %% [markdown]
# ### ✅ PART 2 — Real Heatmap with Labels

# %%
import seaborn as sns
import pandas as pd

data = np.random.rand(6, 6)
df = pd.DataFrame(data, columns=list('ABCDEF'))

sns.heatmap(df, annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Labeled Heatmap")
plt.show()
# Out:
# /usr/lib/python3/dist-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.17.3 and <1.25.0 is required for this version of SciPy (detected version 1.26.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# ### ✅ PART 3 — Contour & Filled Contour Plots

# %%
x = np.linspace(-3, 3, 100)
y = np.linspace(-3, 3, 100)
X, Y = np.meshgrid(x, y)
Z = np.sin(X**2 + Y**2)

# Contour lines
plt.contour(X, Y, Z, levels=20, cmap="plasma")
plt.title("Contour Plot")
plt.colorbar()
plt.show()

# Filled contour
plt.contourf(X, Y, Z, levels=20, cmap="plasma")
plt.title("Filled Contour")
plt.colorbar()
plt.show()
# Out:
# /tmp/ipykernel_12757/4230956437.py:15: MatplotlibDeprecationWarning: Auto-removal of grids by pcolor() and pcolormesh() is deprecated since 3.5 and will be removed two minor releases later; please call grid(False) first.
#   plt.colorbar()

# %% [markdown]
# ### ✅ PART 4 — 3D Plots with Axes3D

# %%
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure(figsize=(6, 4))
ax = fig.add_subplot(111, projection='3d')

x = np.linspace(-5, 5, 50)
y = np.linspace(-5, 5, 50)
X, Y = np.meshgrid(x, y)
Z = np.sin(np.sqrt(X**2 + Y**2))

ax.plot_surface(X, Y, Z, cmap="viridis")
ax.set_title("3D Surface Plot")
plt.show()

# %% [markdown]
# ### ✅ BONUS — 3D Scatter Plot

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

x = np.random.rand(100)
y = np.random.rand(100)
z = np.random.rand(100)

ax.scatter(x, y, z, c=z, cmap='plasma')
ax.set_title("3D Scatter Plot")
plt.show()
